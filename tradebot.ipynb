# %% [markdown]
# # Automated trading test
# ### @kevinofsydney

# %% [markdown]
# TODO
# - Get market data
# - Choose a trading strategy
# - Implement trading strategy
# - Execute order
# - Log all trades
# - Implement stop-loss mechanism
#
# NOTES
# - Alpha Vantage key | AYVLKFE9TEV635R2
# - tradingview.com for charting

# %%
from alpha_vantage.timeseries import TimeSeries
from datetime import datetime, date
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

ts = TimeSeries(key='AYVLKFE9TEV635R2', output_format='pandas')

# %%
# Make an API call to AlphaVantage (limited to 5 calls/min and 500/day)
intradata, metadata = ts.get_intraday(symbol='CBA.AX', interval='1min', outputsize='full')
daydata, metadata = ts.get_daily_adjusted(symbol='CBA.AX', outputsize='full')
daycompact, metadata = ts.get_daily_adjusted(symbol='CBA.AX', outputsize='compact')

# %%
daydata['4. close'].plot()

# %%
daydata.head(10)
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# date
# 2020-01-03    80.97   81.190  80.250     80.31              80.31  1622784.0
# 2020-01-02    79.79   80.220  79.390     79.88              79.88  1416232.0
# 2019-12-31    80.53   80.550  79.800     79.90              79.90  1766363.0
# 2019-12-30    81.25   81.300  80.470     81.10              81.10   905155.0
# 2019-12-27    80.99   81.120  80.550     81.07              81.07  1159836.0
# 2019-12-24    80.72   80.850  80.400     80.71              80.71   783104.0
# 2019-12-23    81.19   81.300  80.750     80.84              80.84  1317871.0
# 2019-12-20    81.86   81.940  81.000     81.25              81.25  7478049.0
# 2019-12-19    82.35   82.380  81.475     81.73              81.73  4093135.0
# 2019-12-18    81.73   82.075  81.510     81.90              81.90  3524114.0
#
#             7. dividend amount  8. split coefficient
# date
# 2020-01-03                 0.0                   1.0
# ...

# %%
daydata = daydata[daydata['4. close'] > 0]
daydata.head(365)['4. close'].plot()

# %%
daycompact['4. close'].plot()

# %%
daydata['2019-09-12']
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# date
# 2019-09-12    81.29    81.46    81.1     81.35              81.35  2795277.0
#
#             7. dividend amount  8. split coefficient
# date
# 2019-09-12                 0.0                   1.0
